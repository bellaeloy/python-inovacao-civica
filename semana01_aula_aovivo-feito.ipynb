# %% [markdown]
# # Exercício
#
# Construa um programa que:
#  - Pergunte a usuária 2 números inteiros;
#  - Crie uma lista numérica do intervalo;
#  - Se o número for divisível por 3, substitua-o por "Tecnologia";
#  - Se o número for divisível por 5, substitua-o por "Cívica";
#  - Se o número for divisível por 3 e 5, substitua-o por "Tecnologia Cívica".

# %%
numero_1 = int(input('Informe um número inteiro: '))
# Out:
# Informe um número inteiro: 1

# %%
numero_1
# Out:
# 1

# %%
numero_2 = int(input('Informe um número inteiro maior que o anterior: '))
# Out:
# Informe um número inteiro maior que o anterior: 20

# %%
numero_2
# Out:
# 20

# %%
#range(numero_inicial, numero_final, passo) -> objeto instanciado. para criar a lista, usamos a conversão abaixo
lista_numero = list(range(numero_1, numero_2))

# %%
lista_vazia = []

# %%
for item in lista_numero:
  if item % 3 == 0 & item % 5 == 0:
    lista_vazia.append(' Tecnologia Cívica')
  elif item % 3 == 0:
    lista_vazia.append('Tecnologia')
  elif item % 5 == 0:
    lista_vazia.append('Cívica')
  else:
    lista_vazia.append(item)


print(lista_vazia)
# Out:
# ['Tecnologia', 'Cívica', 'Tecnologia', 'Tecnologia', 'Cívica', 'Tecnologia', 'Tecnologia', 'Tecnologia', 'Tecnologia', 'Cívica', 'Tecnologia', 'Tecnologia', 'Cívica', 'Tecnologia', 'Tecnologia', 'Tecnologia', 1, 2, ' Tecnologia Cívica', 4, 'Cívica', ' Tecnologia Cívica', 7, 8, ' Tecnologia Cívica', 'Cívica', 11, ' Tecnologia Cívica', 13, 14, ' Tecnologia Cívica', 16, 17, ' Tecnologia Cívica', 19]
